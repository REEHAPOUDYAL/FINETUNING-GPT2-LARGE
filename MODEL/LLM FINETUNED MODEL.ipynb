# %%
# !pip install -q accelerate==0.21.0 peft==0.4.0 bitsandbytes==0.40.2 transformers trl==0.4.7
# !pip install pymongo
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.2/244.2 kB 7.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.9/72.9 kB 5.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.5/92.5 MB 6.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.4/77.4 kB 3.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 25.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 8.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 14.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 11.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 7.9 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...

# %%
pip install transformers

# %%
# !pip install --upgrade trl
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 293.4/293.4 kB 6.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 336.4/336.4 kB 23.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: accelerate
#     Found existing installation: accelerate 0.21.0
#     Uninstalling accelerate-0.21.0:
#       Successfully uninstalled accelerate-0.21.0
#   Attempting uninstall: trl
#     Found existing installation: trl 0.4.7
#     Uninstalling trl-0.4.7:
#       Successfully uninstalled trl-0.4.7
# ...

# %%
# !pip install -U openai
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 454.8/454.8 kB 16.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: openai
#     Found existing installation: openai 1.59.4
#     Uninstalling openai-1.59.4:
#       Successfully uninstalled openai-1.59.4
# ...

# %%
import json

def write_to_jsonl(data, file_path):
    with open(file_path, 'w') as file:
        for entry in data:
            json.dump(entry, file)
            file.write('\n')

def convert_to_gpt2_format(documents):
    fine_tuning_data = []
    for doc in documents:
        prompt = f"What can you tell me about {doc['Attraction Name']} in {doc['District']}?"
        response = (
            f"{doc['Description']} It is mostly visited during the {doc['Mostly Visited Seasons']} season. "
            f"The coordinates are latitude {doc['Latitude']} and longitude {doc['Longitude']}."
        )

        fine_tuning_data.append({
            "text": f"{prompt} {response}"
        })

    return fine_tuning_data
converted_data = convert_to_gpt2_format(documents)
print(converted_data[0]['text'])
# Out:
# What can you tell me about Baraha Temple in Udayapur? A sacred temple complex dedicated to Lord Vishnu, popular among pilgrims. It is mostly visited during the Spring season. The coordinates are latitude 26.83 and longitude 87.18.

# %%
training_file_name = "train.jsonl"
validation_file_name = "val.jsonl"
write_to_jsonl(converted_data, training_file_name)
write_to_jsonl(converted_data, validation_file_name)

# %%
from sklearn.model_selection import train_test_split

train_data, val_data = train_test_split(
    converted_data,
    test_size=0.2,
    random_state=42
)

# %%
pip install openai==1.59.4
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 454.8/454.8 kB 8.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: openai
#     Found existing installation: openai 1.59.6
#     Uninstalling openai-1.59.6:
#       Successfully uninstalled openai-1.59.6
# ...

# %%
pip install transformers

# %%
from transformers import GPT2Tokenizer, GPT2LMHeadModel
model = GPT2LMHeadModel.from_pretrained("gpt2-large")
tokenizer = GPT2Tokenizer.from_pretrained("gpt2-large")
# Out:
# config.json:   0%|          | 0.00/666 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/3.25G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]

# %%
# !pip install -U bitsandbytes
# Out:
# ...
#   Using cached bitsandbytes-0.45.0-py3-none-manylinux_2_24_x86_64.whl.metadata (2.9 kB)
# ...
# Using cached bitsandbytes-0.45.0-py3-none-manylinux_2_24_x86_64.whl (69.1 MB)
# ...
#   Attempting uninstall: bitsandbytes
#     Found existing installation: bitsandbytes 0.40.2
#     Uninstalling bitsandbytes-0.40.2:
#       Successfully uninstalled bitsandbytes-0.40.2
# ...

# %%
from datasets import load_dataset
train_dataset = load_dataset("json", data_files={"train": "./train.jsonl"}, split="train")
val_dataset = load_dataset("json", data_files={"validation": "./val.jsonl"}, split="validation")
print(train_dataset[0])
print(val_dataset[0])
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# {'text': 'What can you tell me about Baraha Temple in Udayapur? A sacred temple complex dedicated to Lord Vishnu, popular among pilgrims. It is mostly visited during the Spring season. The coordinates are latitude 26.83 and longitude 87.18.'}
# {'text': 'What can you tell me about Baraha Temple in Udayapur? A sacred temple complex dedicated to Lord Vishnu, popular among pilgrims. It is mostly visited during the Spring season. The coordinates are latitude 26.83 and longitude 87.18.'}

# %%
from peft import get_peft_model, LoraConfig
lora_config = LoraConfig(
    r=16,
    lora_alpha=32,
    target_modules=["c_attn", "c_proj"],
    lora_dropout=0.1,
    bias="none",
    task_type="CAUSAL_LM",
)
model = get_peft_model(model, lora_config)
# Out:
# /usr/local/lib/python3.10/dist-packages/peft/tuners/lora.py:299: UserWarning: fan_in_fan_out is set to False but the target module is `Conv1D`. Setting fan_in_fan_out to True.
#   warnings.warn(

# %%
pip install datasets

# %%
pip install -U bitsandbytes

# %%
import torch
print(torch.cuda.is_available())
# Out:
# True

# %%
import os
import torch
from datasets import load_dataset
from transformers import (
    GPT2LMHeadModel,
    AutoTokenizer,
    Trainer,
    TrainingArguments,
    AutoModelForCausalLM,
    EarlyStoppingCallback,
)
from transformers import BitsAndBytesConfig
from peft import LoraConfig, get_peft_model
os.makedirs("output", exist_ok=True)
lora_r = 64
lora_alpha = 16
lora_dropout = 0.1
lora_config = LoraConfig(
    r=lora_r,
    lora_alpha=lora_alpha,
    lora_dropout=lora_dropout,
    task_type="CAUSAL_LM"
)
train_dataset = load_dataset("json", data_files={"train": "./train.jsonl"}, split="train")
val_dataset = load_dataset("json", data_files={"validation": "./val.jsonl"}, split="validation")

print("Sample train record:", train_dataset[0])
print("Sample validation record:", val_dataset[0])
use_4bit = True
bnb_4bit_compute_dtype = "float16"
bnb_4bit_quant_type = "nf4"
use_nested_quant = False

compute_dtype = getattr(torch, bnb_4bit_compute_dtype)
bnb_config = BitsAndBytesConfig(
    load_in_4bit=use_4bit,
    bnb_4bit_quant_type=bnb_4bit_quant_type,
    bnb_4bit_compute_dtype=compute_dtype,
    bnb_4bit_use_double_quant=use_nested_quant,
)

device_map = "auto"
model_name = "gpt2-large"
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    quantization_config=bnb_config,
    device_map=device_map
)
model.config.use_cache = False
model.config.pretraining_tp = 1

tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "right"
model = get_peft_model(model, lora_config)
def tokenize_function(examples):
    tokenized_output = tokenizer(
        examples['text'],
        padding="max_length",
        truncation=True,
        max_length=512
    )
    tokenized_output["labels"] = tokenized_output["input_ids"]
    return tokenized_output

tokenized_train_dataset = train_dataset.map(tokenize_function, batched=True)
tokenized_val_dataset   = val_dataset.map(tokenize_function,   batched=True)

training_arguments = TrainingArguments(
    output_dir="./results",
    per_device_train_batch_size=4,
    per_device_eval_batch_size=4,
    gradient_accumulation_steps=1,
    optim="paged_adamw_32bit",
    logging_steps=25,
    learning_rate=2e-4,
    weight_decay=0.001,
    fp16=False,
    bf16=False,
    max_grad_norm=0.3,
    warmup_ratio=0.03,
    group_by_length=True,
    lr_scheduler_type="cosine",
    report_to="tensorboard",

    evaluation_strategy="epoch",
    save_strategy="epoch",
    load_best_model_at_end=True,
    metric_for_best_model="eval_loss",
    greater_is_better=False,
    save_total_limit=2,
)

trainer = Trainer(
    model=model,
    args=training_arguments,
    train_dataset=tokenized_train_dataset,
    eval_dataset=tokenized_val_dataset,
    tokenizer=tokenizer,
    callbacks=[EarlyStoppingCallback(early_stopping_patience=5)]
)

trainer.train()
trainer.save_model("./output/best_model")
tokenizer.save_pretrained("./output/best_model")


last_checkpoint_dir = os.path.join(
    training_arguments.output_dir,
    f"checkpoint-{trainer.state.global_step}"
)

model_last = AutoModelForCausalLM.from_pretrained(last_checkpoint_dir)
model_last.save_pretrained("./output/last_model")
tokenizer.save_pretrained("./output/last_model")

print("Done! Best model saved in ./output/best_model, last model saved in ./output/last_model.")
# Out:
# Sample train record: {'text': 'What can you tell me about Baraha Temple in Udayapur? A sacred temple complex dedicated to Lord Vishnu, popular among pilgrims. It is mostly visited during the Spring season. The coordinates are latitude 26.83 and longitude 87.18.'}
# Sample validation record: {'text': 'What can you tell me about Baraha Temple in Udayapur? A sacred temple complex dedicated to Lord Vishnu, popular among pilgrims. It is mostly visited during the Spring season. The coordinates are latitude 26.83 and longitude 87.18.'}
# ...
# Map:   0%|          | 0/643 [00:00<?, ? examples/s]
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1575: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# <ipython-input-19-2f846e59a65c>:134: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
# ...

# %%
print(model)
# Out:
# PeftModelForCausalLM(
#   (base_model): LoraModel(
#     (model): GPT2LMHeadModel(
#       (transformer): GPT2Model(
#         (wte): Embedding(50257, 1280)
#         (wpe): Embedding(1024, 1280)
#         (drop): Dropout(p=0.1, inplace=False)
#         (h): ModuleList(
#           (0-35): 36 x GPT2Block(
#             (ln_1): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#             (attn): GPT2SdpaAttention(
#               (c_attn): lora.Linear(
#                 (base_layer): Conv1D(nf=3840, nx=1280)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.1, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=1280, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=3840, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
# ...

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
base_model_name = "gpt2-large"
base_model = AutoModelForCausalLM.from_pretrained(base_model_name)
tokenizer = AutoTokenizer.from_pretrained(base_model_name)
base_model.save_pretrained("/content/drive/MyDrive/Checkpoints/base_model")
tokenizer.save_pretrained("/content/drive/MyDrive/Checkpoints/base_model")
# Out:
# config.json:   0%|          | 0.00/666 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/3.25G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# ('/content/drive/MyDrive/Checkpoints/base_model/tokenizer_config.json',
#  '/content/drive/MyDrive/Checkpoints/base_model/special_tokens_map.json',
#  '/content/drive/MyDrive/Checkpoints/base_model/vocab.json',
#  '/content/drive/MyDrive/Checkpoints/base_model/merges.txt',
#  '/content/drive/MyDrive/Checkpoints/base_model/added_tokens.json',
#  '/content/drive/MyDrive/Checkpoints/base_model/tokenizer.json')

# %%
from google.colab import drive
import zipfile
import os
from transformers import AutoModelForCausalLM, AutoTokenizer
import torch

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
zip_file_path = "/content/drive/MyDrive/train2/checkpoint-23667.zip"
extract_path = "/content/drive/MyDrive/train2/checkpoints_extracted"

# %%
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)
print(f"Extracted files to {extract_path}")
checkpoint_dir = extract_path
# Out:
# Extracted files to /content/drive/MyDrive/train2/checkpoints_extracted

# %%
checkpoint_dir = extract_path
tokenizer = AutoTokenizer.from_pretrained(checkpoint_dir)
base_model_name = "gpt2-large"
model = AutoModelForCausalLM.from_pretrained(base_model_name)
# Out:
# config.json:   0%|          | 0.00/666 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/3.25G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]

# %%
from peft import PeftModel
adapter_model = PeftModel.from_pretrained(model, checkpoint_dir)
# Out:
# /usr/local/lib/python3.10/dist-packages/peft/tuners/lora/layer.py:1264: UserWarning: fan_in_fan_out is set to False but the target module is `Conv1D`. Setting fan_in_fan_out to True.
#   warnings.warn(

# %%
input_text = "What can you tell me about Tamor River in Taplejung?"
inputs = tokenizer(input_text, return_tensors="pt")
with torch.no_grad():
    outputs = adapter_model.generate(**inputs, max_length=50)
generated_text = tokenizer.decode(outputs[0], skip_special_tokens=True)

print("Generated Text:", generated_text)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generated Text: What can you tell me about Tamor River in Taplejung? A major river in the region, offering opportunities for rafting and fishing. It is mostly visited during the Autumn season. The coordinates are latitude 27 and longitude 87.8

# %%
pip install streamlit
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 1.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 56.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 94.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 kB 5.9 MB/s eta 0:00:00
# ...

# %%
from peft import PeftModel

# %%
pip install peft

# %%
# !pip install gradio
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 MB 10.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 321.4/321.4 kB 20.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.8/94.8 kB 5.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 57.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.2/73.2 kB 5.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 kB 4.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: markupsafe
#     Found existing installation: MarkupSafe 3.0.2
#     Uninstalling MarkupSafe-3.0.2:
#       Successfully uninstalled MarkupSafe-3.0.2
# ...

# %%
import gradio as gr
import torch
from transformers import AutoTokenizer
from peft import PeftModel

checkpoint_dir = "/content/drive/MyDrive/train2/checkpoints_extracted"
tokenizer = AutoTokenizer.from_pretrained(checkpoint_dir)
adapter_model = PeftModel.from_pretrained(model, checkpoint_dir)
device = "cuda" if torch.cuda.is_available() else "cpu"
adapter_model.to(device)

def generate_response(input_text):
    inputs = tokenizer(input_text, return_tensors="pt").to(device)
    with torch.no_grad():
        outputs = adapter_model.generate(**inputs, max_length=100)
    generated_text = tokenizer.decode(outputs[0], skip_special_tokens=True)

    return generated_text
interface = gr.Interface(
    fn=generate_response,
    inputs=gr.Textbox(label="Ask a question or give a prompt"),
    outputs=gr.Textbox(label="Generated Response"),
    title="Model Inference App",
    description="Ask any question or give a prompt to get a generated response."
)
interface.launch(share=True)
# Out:
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://026a01eecdb07b5d45.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://026a01eecdb07b5d45.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
